# %% [markdown]
# # This is for the testing purpose

# %%
import os
import json
import pandas as pd
from datetime import datetime
from  dotenv import load_dotenv
import requests 
import numpy as np
import psycopg2
from psycopg2 import sql


print("Packages are done loading")
# Out:
# Packages are done loading

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\Student\End-to-End-API-to-Postgres

# %%
import os

print(os.listdir())
# Out:
# ['.env', '.git', '.gitignore', '.venv', 'assets', 'main.py', 'test.ipynb']

# %%
from dotenv import find_dotenv

print(find_dotenv())
# Out:
# c:\Users\Student\End-to-End-API-to-Postgres\.env

# %%
load_dotenv(r"\.env")
# Out:
# False

# %%
API_KEY = os.getenv("API_KEY")
API_HOST = os.getenv("API_HOST")
LOCATION = "New York, NY"
